# %%
import pandas as pd

# %%
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# - punkt: The ‘punkt’ package is a pre-trained model that helps the library to split text into sentences and words efficiently.
# - ‘stopwords’: This is the identifier for the stopwords corpus that you want to download. This corpus contains lists of stopwords for several languages.
# - ‘wordnet’: This is the identifier for the WordNet lexical database that you want to download. It is a valuable resource for tasks such as semantic reasoning, natural language understanding, and language translation.

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kaveh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kaveh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kaveh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# import spacy_transformers
import preprocessor as p

# %%
import torch
import spacy
from spacy.util import minibatch, compounding
# import spacy_transformers
from spacy.tokens import Doc
from spacy.training import Example
from spacy.training.example import Example

# %%
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# https://github.com/NeelShah18/emot/blob/master/emot/emo_unicode.py  emoticons list
# https://github.com/rishabhverma17/sms_slang_translator/blob/master/slang.txt Chat shortcuts

def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r' ', text)

def remove_punctuations(text):
    punctuations = re.compile(r'[~`!@#$%^&*(,<،>){}\\/|\'"?؟_+-=~\[\]]')
    return punctuations.sub(r' ', text)

def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r' ', text)

def remove_weird_chars(text):
    weridPatterns = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u'\U00010000-\U0010ffff'
                               u"\u200d"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\u3030"
                               u"\ufe0f"
                               u"\u2069"
                               u"\u2066"
                               u"\u200c"
                               u"\u2068"
                               u"\u2067"
                               "]+", flags=re.UNICODE)
    patterns = [re.compile('\r'), re.compile('\n'), re.compile('&amp;')]
    text = weridPatterns.sub(r'', text)
    for p in patterns:
        text = p.sub(r' ', text)
    return text

def remove_extra_repeated_alpha(text):
    """
    Remove extra repeated alphabets in a word
    check these links:
    demo : https://regex101.com/r/ALxocA/1
    Question: https://bit.ly/2DoiPqS
    """
    return re.sub(r'([^\W\d_])\1{2,}', r'\1', text)

# %%
def first_step_cleaning(text):
    # text = text.encode('utf-8')
    # Remove extra spaces
    text = re.sub('\s+', ' ', str(text)).strip()
    # text = text.replace('-',' ')
    # Remove numbers
    # text = re.sub('\d+', '', text)
    # Case normalization
    text = text.lower()
    # text = p.clean(text).replace("Image","").replace("profile picture","").replace("  ","")
    # Remove URLs, HTML tags, and non-alphanumeric characters
    text = text.replace("\\xc2\\xa9","")
    text = text.replace("\n","")
    text = text.replace("..","")
    text = text.replace("     ","")
    text = text.replace("    ","")
    text = text.replace("   ","")
    text = text.replace("  ","")
    text = text.replace(" – "," ")
    text = text.replace("\x0c","")
    text = text.replace(r"\u0107","")
    text = text.replace(r"'","")
    text = text.replace(r'"','')
    text = text.replace(rem_01,"")
    text = text.replace(rem_02,"")
    text = text.replace(rem_03,"")
    for i in range(50):
        text = text.replace("\n{}".format(i),"")
    for i in range(500):
        text = text.replace(r"\u0{}".format(i),"")
    # text = re.sub(r'http\S+', '', single_string)
    # text = re.sub('<[^>]*>', '', text)
    # text = re.sub('[^a-zA-Z0-9]', ' ', text)
    text = remove_urls(text)
    text = remove_html(text)
    text = remove_weird_chars(text)
    text = remove_extra_repeated_alpha(text)
    # Remove punctuations
    # text = "".join([char for char in text if char not in string.punctuation])
    return text

# %%
def second_step_cleaning_tokenizing(text):
    # Remove all punctuation except the ones to keep
    translator = str.maketrans('', '', string.punctuation.replace('/', '').replace('-',''))
    text = text.translate(translator)
    # Tokenization
    tokens = word_tokenize(text)

    # Stopword removal
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]

    # Stemming
    stemmer = SnowballStemmer("english")
    stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]

    # Lemmatization
    wnl = WordNetLemmatizer()
    lemmatized_tokens = [wnl.lemmatize(word) for word in stemmed_tokens]

    return lemmatized_tokens

# %%
raw_df = pd.read_csv(r"Mohammad_Karimadini_Crawling.csv")
# raw_df.drop(columns=["Unnamed: 0"],inplace = True)
raw_df
# Out:
#     12. Do we need different measures to ensure all segments of the road transport sector are able to reduce emissions, and if so what government and industry measures might well support the uptake of electric bikes, micro-mobility and motorbikes?  \
# 0    Yes, please.\nPlease follow the Climate Counci...
# 1                                                  NaN
# 2                                                  NaN
# 3    Different measures are no doubt needed to supp...
# 4                                                  NaN
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     8. Would vehicle fuel efficiency standards incentivise global manufacturers to send EVs and lower emission vehicles to Australia?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    The evidence suggets that they do encourage this.
# 4    Fuel should no longer be relevant in these dis...
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     3. What are suitable indicators to measure if we are on track to achieve our goals and objectives?  \
# 0    Rapidly reduce sales of ICE vehicles\nRapidly ...
# 1                                                  NaN
# 2                                                  NaN
# 3    Setting a target year for banning ICE vehicle ...
# 4    Uptake of EVs, increase of charge station avai...
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     15. What actions can governments and industry take to strengthen our competitiveness and innovate across the full lifecycle of the EV value chain?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Supporting the full lifecyle of battery manufa...
# 4             Support shipping vehicles to the country
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     16. How can we expand our existing domestic heavy vehicle manufacturing and assembly capability?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Priotising locally made heavy vehicle and bus ...
# 4                                                  NaN
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     1. Do you agree with the objectives and do you think they will achieve our proposed goals? Are there other objectives we should consider?  \
# 0    I agree with the current objectives, however s...
# 1                                                  NaN
# 2                                                  NaN
# 3    It's unclear whether "establishing systems and...
# 4    We should not tie ourselves to Australian manu...
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     6. What information could help increase demand and is Government or industry best placed to inform Australians about EVs?  \
# 0    The Government should be informing Australians...
# 1    Government. "Industry", (the local distributor...
# 2                                                  NaN
# 3    Government and industry both have a role to pl...
# 4    A similar body to the AER may be needed to assist
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     7. Are vehicle fuel efficiency standards an effective mechanism to reduce passenger and light commercial fleet emissions?  \
# 0    Yes, as shown in the EU etc. Please introduce ...
# 1                                                  NaN
# 2                                                  NaN
# 3    Indications are that fuel efficiency standards...
# 4                                                   No
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     What area best describes where you live?  \
# 0                                       City
# 1                                       City
# 2                                       City
# 3                                       City
# 4                                       City
# ..                                       ...
# 442                            Regional area
# 443                            Regional area
# 444                            Regional area
# 445                                     City
# 446                                     City
#
#     18. Are there other proposals that could help drive demand for EVs and provide a revenue source to help fund road infrastructure?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Fuel excise is not currently utilised for road...
# 4                                                  NaN
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#      ... What state or territory do you live in?  \
# 0    ...                         New South Wales
# 1    ...                         New South Wales
# 2    ...                                Victoria
# 3    ...                         New South Wales
# 4    ...                                Victoria
# ..   ...                                     ...
# 442  ...                         New South Wales
# 443  ...                         New South Wales
# 444  ...                         New South Wales
# 445  ...                         New South Wales
# 446  ...                                Victoria
#
#     5. Over what timeframe should we be incentivising low emission vehicles as we transition to zero emission vehicles?  \
# 0    Please do not incentivise hybrids or plug-in h...
# 1                                                  NaN
# 2                                                  NaN
# 3    Only BEVs should be incentivised, the rest are...
# 4        10 year timeframe to allow for infrastructure
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     17. Is it viable to extend Australian domestic manufacturing and assembly capability to other vehicle classes?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Absolutely and it is already being done for ma...
# 4                                                  NaN
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     10. What design features should the Government consider in more detail for vehicle fuel efficiency standards, including level of ambition, who they should apply to, commencement date, penalties and enforcement?  \
# 0            World-best ambition, as soon as possible.
# 1                                                  NaN
# 2                                                  NaN
# 3    Government should consider best practice stand...
# 4                                                  NaN
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     20. How can we best make sure all Australians get access to the opportunities and benefits from the transition?  \
# 0    Make riding a bike safe and accessible, as thi...
# 1                                                  NaN
# 2                                                  NaN
# 3    Structure incentives appropriately and look at...
# 4                                                  NaN
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#                                 Make a general comment  \
# 0    I took two kids in a pram on a bus to a street...
# 1    If you want more EVs in Australia allow free t...
# 2                                                  NaN
# 3    Australia is ready for bold and strong commitm...
# 4    People in high density housing have no chance ...
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444  The attachment is in “Pages” (IOS platform) wh...
# 445                                                NaN
# 446                                                NaN
#
#     9. In addition to vehicle fuel efficiency standards for passenger and light commercial vehicles, would vehicle fuel efficiency standards be an appropriate mechanism to increase the supply of heavy vehicle classes to Australia?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Fuel efficiency standards would no doubt incre...
# 4                                                  NaN
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#                                                 Titles number_of_q_answered  \
# 0                                      #460\nAnonymous                   14
# 1                                      #456\nAnonymous                   21
# 2                                      #449\nAnonymous                   23
# 3                                      #438\nAnonymous                   46
# 4                                      #432\nAnonymous                   59
# ..                                                 ...                  ...
# 442                               #409\nWilliam Adlong                 4833
# 443                                  #301\nWinZero Inc                 4835
# 444  #312\nWodonga Albury Towards Climate Health (W...                 4838
# 445                             #436\nWoolworths Group                 4840
# 446     #320\nZoe Daniel, Federal Member for Goldstein                 4842
#
#                                   links_crawled_listed
# 0    https://consult.dcceew.gov.au/national-electri...
# 1    https://consult.dcceew.gov.au/national-electri...
# 2    https://consult.dcceew.gov.au/national-electri...
# 3    https://consult.dcceew.gov.au/national-electri...
# 4    https://consult.dcceew.gov.au/national-electri...
# ..                                                 ...
# 442  https://consult.dcceew.gov.au/national-electri...
# 443  https://consult.dcceew.gov.au/national-electri...
# 444  https://consult.dcceew.gov.au/national-electri...
# 445  https://consult.dcceew.gov.au/national-electri...
# 446  https://consult.dcceew.gov.au/national-electri...
#
# [447 rows x 26 columns]

# %%
keep_rows_bool = []
for i in range(len(raw_df)):
    # combine all values of row 0 to one string
    # row_str = ''.join(raw_df.iloc[i,:-3].dropna().astype(str)).replace("\n","")
    keep_rows_bool.append(raw_df.iloc[i,:-3].isna().sum() < 19)

# %%
raw_df["keep_rows_bool"] = keep_rows_bool
raw_df
# Out:
#     12. Do we need different measures to ensure all segments of the road transport sector are able to reduce emissions, and if so what government and industry measures might well support the uptake of electric bikes, micro-mobility and motorbikes?  \
# 0    Yes, please.\nPlease follow the Climate Counci...
# 1                                                  NaN
# 2                                                  NaN
# 3    Different measures are no doubt needed to supp...
# 4                                                  NaN
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     8. Would vehicle fuel efficiency standards incentivise global manufacturers to send EVs and lower emission vehicles to Australia?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    The evidence suggets that they do encourage this.
# 4    Fuel should no longer be relevant in these dis...
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     3. What are suitable indicators to measure if we are on track to achieve our goals and objectives?  \
# 0    Rapidly reduce sales of ICE vehicles\nRapidly ...
# 1                                                  NaN
# 2                                                  NaN
# 3    Setting a target year for banning ICE vehicle ...
# 4    Uptake of EVs, increase of charge station avai...
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     15. What actions can governments and industry take to strengthen our competitiveness and innovate across the full lifecycle of the EV value chain?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Supporting the full lifecyle of battery manufa...
# 4             Support shipping vehicles to the country
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     16. How can we expand our existing domestic heavy vehicle manufacturing and assembly capability?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Priotising locally made heavy vehicle and bus ...
# 4                                                  NaN
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     1. Do you agree with the objectives and do you think they will achieve our proposed goals? Are there other objectives we should consider?  \
# 0    I agree with the current objectives, however s...
# 1                                                  NaN
# 2                                                  NaN
# 3    It's unclear whether "establishing systems and...
# 4    We should not tie ourselves to Australian manu...
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     6. What information could help increase demand and is Government or industry best placed to inform Australians about EVs?  \
# 0    The Government should be informing Australians...
# 1    Government. "Industry", (the local distributor...
# 2                                                  NaN
# 3    Government and industry both have a role to pl...
# 4    A similar body to the AER may be needed to assist
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     7. Are vehicle fuel efficiency standards an effective mechanism to reduce passenger and light commercial fleet emissions?  \
# 0    Yes, as shown in the EU etc. Please introduce ...
# 1                                                  NaN
# 2                                                  NaN
# 3    Indications are that fuel efficiency standards...
# 4                                                   No
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     What area best describes where you live?  \
# 0                                       City
# 1                                       City
# 2                                       City
# 3                                       City
# 4                                       City
# ..                                       ...
# 442                            Regional area
# 443                            Regional area
# 444                            Regional area
# 445                                     City
# 446                                     City
#
#     18. Are there other proposals that could help drive demand for EVs and provide a revenue source to help fund road infrastructure?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Fuel excise is not currently utilised for road...
# 4                                                  NaN
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 442  ...
# 443  ...
# 444  ...
# 445  ...
# 446  ...
#
#     5. Over what timeframe should we be incentivising low emission vehicles as we transition to zero emission vehicles?  \
# 0    Please do not incentivise hybrids or plug-in h...
# 1                                                  NaN
# 2                                                  NaN
# 3    Only BEVs should be incentivised, the rest are...
# 4        10 year timeframe to allow for infrastructure
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     17. Is it viable to extend Australian domestic manufacturing and assembly capability to other vehicle classes?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Absolutely and it is already being done for ma...
# 4                                                  NaN
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     10. What design features should the Government consider in more detail for vehicle fuel efficiency standards, including level of ambition, who they should apply to, commencement date, penalties and enforcement?  \
# 0            World-best ambition, as soon as possible.
# 1                                                  NaN
# 2                                                  NaN
# 3    Government should consider best practice stand...
# 4                                                  NaN
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#     20. How can we best make sure all Australians get access to the opportunities and benefits from the transition?  \
# 0    Make riding a bike safe and accessible, as thi...
# 1                                                  NaN
# 2                                                  NaN
# 3    Structure incentives appropriately and look at...
# 4                                                  NaN
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#                                 Make a general comment  \
# 0    I took two kids in a pram on a bus to a street...
# 1    If you want more EVs in Australia allow free t...
# 2                                                  NaN
# 3    Australia is ready for bold and strong commitm...
# 4    People in high density housing have no chance ...
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444  The attachment is in “Pages” (IOS platform) wh...
# 445                                                NaN
# 446                                                NaN
#
#     9. In addition to vehicle fuel efficiency standards for passenger and light commercial vehicles, would vehicle fuel efficiency standards be an appropriate mechanism to increase the supply of heavy vehicle classes to Australia?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Fuel efficiency standards would no doubt incre...
# 4                                                  NaN
# ..                                                 ...
# 442                                                NaN
# 443                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
#
#                                                 Titles number_of_q_answered  \
# 0                                      #460\nAnonymous                   14
# 1                                      #456\nAnonymous                   21
# 2                                      #449\nAnonymous                   23
# 3                                      #438\nAnonymous                   46
# 4                                      #432\nAnonymous                   59
# ..                                                 ...                  ...
# 442                               #409\nWilliam Adlong                 4833
# 443                                  #301\nWinZero Inc                 4835
# 444  #312\nWodonga Albury Towards Climate Health (W...                 4838
# 445                             #436\nWoolworths Group                 4840
# 446     #320\nZoe Daniel, Federal Member for Goldstein                 4842
#
#                                   links_crawled_listed keep_rows_bool
# 0    https://consult.dcceew.gov.au/national-electri...           True
# 1    https://consult.dcceew.gov.au/national-electri...           True
# 2    https://consult.dcceew.gov.au/national-electri...          False
# 3    https://consult.dcceew.gov.au/national-electri...           True
# 4    https://consult.dcceew.gov.au/national-electri...           True
# ..                                                 ...            ...
# 442  https://consult.dcceew.gov.au/national-electri...          False
# 443  https://consult.dcceew.gov.au/national-electri...          False
# 444  https://consult.dcceew.gov.au/national-electri...          False
# 445  https://consult.dcceew.gov.au/national-electri...          False
# 446  https://consult.dcceew.gov.au/national-electri...          False
#
# [447 rows x 27 columns]

# %%
raw_df.to_csv("CheckPoint_01_MK_P_01.csv",index=False)

# %% [markdown]
# # CheckPoint_01

# %%
raw_df = raw_df[raw_df["keep_rows_bool"]]

# %%
len(raw_df)
# Out:
# 241

# %%
raw_df.columns
# Out:
# Index(['12. Do we need different measures to ensure all segments of the road transport sector are able to reduce emissions, and if so what government and industry measures might well support the uptake of electric bikes, micro-mobility and motorbikes?',
#        '8. Would vehicle fuel efficiency standards incentivise global manufacturers to send EVs and lower emission vehicles to Australia?',
#        '3. What are suitable indicators to measure if we are on track to achieve our goals and objectives?',
#        '15. What actions can governments and industry take to strengthen our competitiveness and innovate across the full lifecycle of the EV value chain?',
#        '16. How can we expand our existing domestic heavy vehicle manufacturing and assembly capability?',
#        '1. Do you agree with the objectives and do you think they will achieve our proposed goals? Are there other objectives we should consider?',
#        '6. What information could help increase demand and is Government or industry best placed to inform Australians about EVs?',
#        '7. Are vehicle fuel efficiency standards an effective mechanism to reduce passenger and light commercial fleet emissions?',
#        'What area best describes where you live?',
#        '18. Are there other proposals that could help drive demand for EVs and provide a revenue source to help fund road infrastructure?',
#        '14. Should the Government consider ways to increase the supply of second hand EVs independently imported to the Australian market? Could the safety and consumer risks of this approach be mitigated?',
#        '11. What policies and/or industry actions could complement vehicle fuel efficiency standards to help increase supply of EVs to Australia and electrify the Australian fleet?',
#        '2. What are the implications if other countries accelerate EV uptake faster than Australia?',
#        '13. How could we best increase the number of affordable second hand EVs?',
#        '4. Are there other measures by governments and industry that could increase affordability and accessibility of EVs to help drive demand?',
#        '19. What more needs to be done nationally to ensure we deliver a nationally comprehensive framework for EVs?',
#        'What state or territory do you live in?',
#        '5. Over what timeframe should we be incentivising low emission vehicles as we transition to zero emission vehicles?',
#        '17. Is it viable to extend Australian domestic manufacturing and assembly capability to other vehicle classes?',
#        '10. What design features should the Government consider in more detail for vehicle fuel efficiency standards, including level of ambition, who they should apply to, commencement date, penalties and enforcement?',
#        '20. How can we best make sure all Australians get access to the opportunities and benefits from the transition?',
#        'Make a general comment',
#        '9. In addition to vehicle fuel efficiency standards for passenger and light commercial vehicles, would vehicle fuel efficiency standards be an appropriate mechanism to increase the supply of heavy vehicle classes to Australia?',
#        'Titles', 'number_of_q_answered', 'links_crawled_listed',
#        'keep_rows_bool'],
#       dtype='object')

# %%
combined_values = []
for i in range(len(raw_df)):
    # combine all values of row 0 to one string
    row_str = ''.join(raw_df.iloc[i,:-4].dropna().astype(str)).replace("\n","")
    combined_values.append(row_str)

# %%
len(combined_values)
# Out:
# 241

# %%
combined_values[4]
# Out:
# "Yes, fuel efficiency standards would send an important market signal to manufacturers. They would need to be introduced fairly quickly to avoid dumping of cheaper, less efficient vehicles before their importation was banned. There might need to be a tax on large inventories of less fuel efficient vehicles.- Increasing the number and proportion of new and second-hand EV registrations overall- The availability and takeup of more electricity-efficient EVs for people who don't need high-performance vehicles.- The proportion of workplaces and commuter carparks which offer EV charging facilities- The amount of otherwise unused electricity from rooftop solar being used instead to charge EVs during daylight hours, and the takeup of bidirectional charging to improve grid capacity during peak periods.Provide TAFE places to train mechanics in the maintenance and repair of EVs, tax incentives for domestic EV vehicle and component manufacturing, and for the repurposing of batteries no longer usable in vehicles but suitable for other applications such as home or community electricity storage.Provide incentives for the repurposing of batteries no longer suitable for EVsThe objectives should be broadened to include electrification of major interstate rail routes, incentives to move more freight onto rail (and thus the number of heavy road vehicles on major routes), and proper weight-based road user charges for heavy vehiclesThere is a role for both government and industry, but government needs to take the lead.Measures should include Information about the comparative long-term costs of EVs and ICE vehicles in various scenarios (e.g. mostly daily city commutes, regular longer-distance driving in regional areas). This would include information on the real-world range each vehicle could realistically be expected to achieve at nominal charging conditions (say 10 to 80 per cent), with allowances for Australian conditions, rather than just the WLTP figure.Prominent road signs pointing to public EV charging facilities in urban and regional areas, and along highways, ideally showing real-time availability of those chargers.Interoperability between commercial chargers (avoiding the need for separate cards or apps for each operator).A 'show rather than just tell' approach, in government-sponsored information campaigns might, have people to talk about their EV experiences, such as how they overcame their initial scepticism.Anecdotally, some car dealers are reluctant to promote EVs to consumers. Perhaps government could provide a small incentive payment to dealers who encourage customers to look at EV models.Yes, they are important in reducing emissions, in the same way that the phasing out of leaded petrol in the 1980s produced positive health outcomes. People would need to be reassured that higher fuel standards would not adversely affect existing vehicles, nor significantly increase their fuel costs.CityDistance-based road user charges for all vehicles based on axle weights for all light and heavy vehicles. Congestion charges,with a weighting based on emissions (i.e. lower charges for low and no-emission vehicles)/Yes, by simplifying the import of right-hand-drive 2nd hand vehicle which meet key safety rules.Australia will continue to be a dumping ground for ICE vehicles, and most EV manufacturers will continue to preference other countries, furthering the market dominance of Tesla to the exclusion of other brands and possibly stifling local EV manufacturing.A lack of supply will also further delay development of a domestic second-hand market.By encouraging governments and other fleet buyers (including car rental firms) to buy EV fleets wherever possible.Developing incentives, standards and kits for people wanting to convert ICE vehicles to electric operationRequiring the fitting (and over time retro-fitting) of powerpoints and/or EV chargers in apartment building carparksIncentives to encourage service station owners to provide rapid EV charging (an ...

# %%
raw_df["combined_values"] = combined_values
# Out:
# C:\Users\kaveh\AppData\Local\Temp\ipykernel_19284\2614057231.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_df["combined_values"] = combined_values

# %%
raw_df
# Out:
#     12. Do we need different measures to ensure all segments of the road transport sector are able to reduce emissions, and if so what government and industry measures might well support the uptake of electric bikes, micro-mobility and motorbikes?  \
# 0    Yes, please.\nPlease follow the Climate Counci...
# 1                                                  NaN
# 3    Different measures are no doubt needed to supp...
# 4                                                  NaN
# 5                                                  NaN
# ..                                                 ...
# 420  See answers supplied by email and in the attac...
# 433                                                NaN
# 436  It is important to focus on the main polluters...
# 439  Please refer to the attached document for our ...
# 441  1. Provide free registration and accident insu...
#
#     8. Would vehicle fuel efficiency standards incentivise global manufacturers to send EVs and lower emission vehicles to Australia?  \
# 0                                                  NaN
# 1                                                  NaN
# 3    The evidence suggets that they do encourage this.
# 4    Fuel should no longer be relevant in these dis...
# 5    Yes, fuel efficiency standards would send an i...
# ..                                                 ...
# 420  See answers supplied by email and in the attac...
# 433                                                NaN
# 436                                                yes
# 439  Please refer to the attached document for our ...
# 441  Of course. No brainer. Time to end the dumping...
#
#     3. What are suitable indicators to measure if we are on track to achieve our goals and objectives?  \
# 0    Rapidly reduce sales of ICE vehicles\nRapidly ...
# 1                                                  NaN
# 3    Setting a target year for banning ICE vehicle ...
# 4    Uptake of EVs, increase of charge station avai...
# 5    - Increasing the number and proportion of new ...
# ..                                                 ...
# 420  See answers supplied by email and in the attac...
# 433                             Please see my response
# 436  percentage of EVs sold in comparison to ICE ve...
# 439  Please refer to the attached document for our ...
# 441  1. EV sales uptake to beon tract to 100% by 20...
#
#     15. What actions can governments and industry take to strengthen our competitiveness and innovate across the full lifecycle of the EV value chain?  \
# 0                                                  NaN
# 1                                                  NaN
# 3    Supporting the full lifecyle of battery manufa...
# 4             Support shipping vehicles to the country
# 5    Provide TAFE places to train mechanics in the ...
# ..                                                 ...
# 420  See answers supplied by email and in the attac...
# 433                                                NaN
# 436                                                NaN
# 439  Please refer to the attached document for our ...
# 441  1. Subsidy of $50 per KW of EV battery pack if...
#
#     16. How can we expand our existing domestic heavy vehicle manufacturing and assembly capability?  \
# 0                                                  NaN
# 1                                                  NaN
# 3    Priotising locally made heavy vehicle and bus ...
# 4                                                  NaN
# 5                                                  NaN
# ..                                                 ...
# 420  See answers supplied by email and in the attac...
# 433                                                NaN
# 436                                                NaN
# 439  Please refer to the attached document for our ...
# 441  Subsidy of $50 per KW of EV battery pack if th...
#
#     1. Do you agree with the objectives and do you think they will achieve our proposed goals? Are there other objectives we should consider?  \
# 0    I agree with the current objectives, however s...
# 1                                                  NaN
# 3    It's unclear whether "establishing systems and...
# 4    We should not tie ourselves to Australian manu...
# 5    The objectives should be broadened to include ...
# ..                                                 ...
# 420  See answers supplied by email and in the attac...
# 433                             Please see my response
# 436  Yes and yes.\nIncreasing fuel independence sho...
# 439  Please refer to the attached document for our ...
# 441                                                NaN
#
#     6. What information could help increase demand and is Government or industry best placed to inform Australians about EVs?  \
# 0    The Government should be informing Australians...
# 1    Government. "Industry", (the local distributor...
# 3    Government and industry both have a role to pl...
# 4    A similar body to the AER may be needed to assist
# 5    There is a role for both government and indust...
# ..                                                 ...
# 420  See answers supplied by email and in the attac...
# 433                                                NaN
# 436  Government to provide statistics on EV uptake ...
# 439  Please refer to the attached document for our ...
# 441  1. Wide spread dissemination of the % of Austr...
#
#     7. Are vehicle fuel efficiency standards an effective mechanism to reduce passenger and light commercial fleet emissions?  \
# 0    Yes, as shown in the EU etc. Please introduce ...
# 1                                                  NaN
# 3    Indications are that fuel efficiency standards...
# 4                                                   No
# 5    Yes, they are important in reducing emissions,...
# ..                                                 ...
# 420  See answers supplied by email and in the attac...
# 433                                                NaN
# 436                                                yes
# 439  Please refer to the attached document for our ...
# 441  Yes they help but would be more effective if t...
#
#     What area best describes where you live?  \
# 0                                       City
# 1                                       City
# 3                                       City
# 4                                       City
# 5                                       City
# ..                                       ...
# 420                                     City
# 433                                     City
# 436                                     City
# 439                                     City
# 441                            Regional area
#
#     18. Are there other proposals that could help drive demand for EVs and provide a revenue source to help fund road infrastructure?  \
# 0                                                  NaN
# 1                                                  NaN
# 3    Fuel excise is not currently utilised for road...
# 4                                                  NaN
# 5    Distance-based road user charges for all vehic...
# ..                                                 ...
# 420  See answers supplied by email and in the attac...
# 433                                                NaN
# 436  The earlier proposed RUC policy is ideally sui...
# 439  Please refer to the attached document for our ...
# 441                                                NaN
#
#      ...  \
# 0    ...
# 1    ...
# 3    ...
# 4    ...
# 5    ...
# ..   ...
# 420  ...
# 433  ...
# 436  ...
# 439  ...
# 441  ...
#
#     17. Is it viable to extend Australian domestic manufacturing and assembly capability to other vehicle classes?  \
# 0                                                  NaN
# 1                                                  NaN
# 3    Absolutely and it is already being done for ma...
# 4                                                  NaN
# 5                                                  NaN
# ..                                                 ...
# 420  See answers supplied by email and in the attac...
# 433                                                NaN
# 436                                                NaN
# 439  Please refer to the attached document for our ...
# 441  Yes and we should. For example: Offer land, su...
#
#     10. What design features should the Government consider in more detail for vehicle fuel efficiency standards, including level of ambition, who they should apply to, commencement date, penalties and enforcement?  \
# 0            World-best ambition, as soon as possible.
# 1                                                  NaN
# 3    Government should consider best practice stand...
# 4                                                  NaN
# 5    Adoption of European standards would be approp...
# ..                                                 ...
# 420  See answers supplied by email and in the attac...
# 433                                                NaN
# 436                                                NaN
# 439  Please refer to the attached document for our ...
# 441  2030 ban on new petrol and diesel vehicles sal...
#
#     20. How can we best make sure all Australians get access to the opportunities and benefits from the transition?  \
# 0    Make riding a bike safe and accessible, as thi...
# 1                                                  NaN
# 3    Structure incentives appropriately and look at...
# 4                                                  NaN
# 5                                                  NaN
# ..                                                 ...
# 420  See answers supplied by email and in the attac...
# 433                                                NaN
# 436                                                NaN
# 439  Please refer to the attached document for our ...
# 441  Make the purchase of EV the only viable choice...
#
#                                 Make a general comment  \
# 0    I took two kids in a pram on a bus to a street...
# 1    If you want more EVs in Australia allow free t...
# 3    Australia is ready for bold and strong commitm...
# 4    People in high density housing have no chance ...
# 5    Thank you for the opportunity to make a submis...
# ..                                                 ...
# 420                                                NaN
# 433                                                NaN
# 436  The comments made in the submission may be rep...
# 439                                                NaN
# 441  Our business has made the transition to all EV...
#
#     9. In addition to vehicle fuel efficiency standards for passenger and light commercial vehicles, would vehicle fuel efficiency standards be an appropriate mechanism to increase the supply of heavy vehicle classes to Australia?  \
# 0                                                  NaN
# 1                                                  NaN
# 3    Fuel efficiency standards would no doubt incre...
# 4                                                  NaN
# 5    Fuel efficiency standards for heavy vehicles a...
# ..                                                 ...
# 420  See answers supplied by email and in the attac...
# 433                                                NaN
# 436                                                NaN
# 439  Please refer to the attached document for our ...
# 441  Yes of course. It is essential to our survival...
#
#                                                 Titles number_of_q_answered  \
# 0                                      #460\nAnonymous                   14
# 1                                      #456\nAnonymous                   21
# 3                                      #438\nAnonymous                   46
# 4                                      #432\nAnonymous                   59
# 5                                      #352\nAnonymous                   77
# ..                                                 ...                  ...
# 420                               #466\nTim O'Loughlin                 4734
# 433                            #435\nVolgren Australia                 4765
# 436                                      #113\nWatts4U                 4786
# 439  #455\nWestern Sydney Regional Organisation of ...                 4812
# 441                    #315\nWhyalla Veterinary Clinic                 4831
#
#                                   links_crawled_listed keep_rows_bool  \
# 0    https://consult.dcceew.gov.au/national-electri...           True
# 1    https://consult.dcceew.gov.au/national-electri...           True
# 3    https://consult.dcceew.gov.au/national-electri...           True
# 4    https://consult.dcceew.gov.au/national-electri...           True
# 5    https://consult.dcceew.gov.au/national-electri...           True
# ..                                                 ...            ...
# 420  https://consult.dcceew.gov.au/national-electri...           True
# 433  https://consult.dcceew.gov.au/national-electri...           True
# 436  https://consult.dcceew.gov.au/national-electri...           True
# 439  https://consult.dcceew.gov.au/national-electri...           True
# 441  https://consult.dcceew.gov.au/national-electri...           True
#
#                                        combined_values
# 0    Yes, please.Please follow the Climate Council ...
# 1    Government. "Industry", (the local distributor...
# 3    Different measures are no doubt needed to supp...
# 4    Fuel should no longer be relevant in these dis...
# 5    Yes, fuel efficiency standards would send an i...
# ..                                                 ...
# 420  See answers supplied by email and in the attac...
# 433  Please see my responsePlease see my responseCi...
# 436  It is important to focus on the main polluters...
# 439  Please refer to the attached document for our ...
# 441  1. Provide free registration and accident insu...
#
# [241 rows x 28 columns]

# %%
raw_df.to_csv("CheckPoint_02_MK_P_01.csv",index=False)

# %% [markdown]
# # Checkpoint_02
# ## step 1 of cleaning

# %%
combined_df = pd.read_csv("CheckPoint_02_MK_P_01.csv")
combined_df
# Out:
#     12. Do we need different measures to ensure all segments of the road transport sector are able to reduce emissions, and if so what government and industry measures might well support the uptake of electric bikes, micro-mobility and motorbikes?  \
# 0    Yes, please.\nPlease follow the Climate Counci...
# 1                                                  NaN
# 2    Different measures are no doubt needed to supp...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 236  See answers supplied by email and in the attac...
# 237                                                NaN
# 238  It is important to focus on the main polluters...
# 239  Please refer to the attached document for our ...
# 240  1. Provide free registration and accident insu...
#
#     8. Would vehicle fuel efficiency standards incentivise global manufacturers to send EVs and lower emission vehicles to Australia?  \
# 0                                                  NaN
# 1                                                  NaN
# 2    The evidence suggets that they do encourage this.
# 3    Fuel should no longer be relevant in these dis...
# 4    Yes, fuel efficiency standards would send an i...
# ..                                                 ...
# 236  See answers supplied by email and in the attac...
# 237                                                NaN
# 238                                                yes
# 239  Please refer to the attached document for our ...
# 240  Of course. No brainer. Time to end the dumping...
#
#     3. What are suitable indicators to measure if we are on track to achieve our goals and objectives?  \
# 0    Rapidly reduce sales of ICE vehicles\nRapidly ...
# 1                                                  NaN
# 2    Setting a target year for banning ICE vehicle ...
# 3    Uptake of EVs, increase of charge station avai...
# 4    - Increasing the number and proportion of new ...
# ..                                                 ...
# 236  See answers supplied by email and in the attac...
# 237                             Please see my response
# 238  percentage of EVs sold in comparison to ICE ve...
# 239  Please refer to the attached document for our ...
# 240  1. EV sales uptake to beon tract to 100% by 20...
#
#     15. What actions can governments and industry take to strengthen our competitiveness and innovate across the full lifecycle of the EV value chain?  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Supporting the full lifecyle of battery manufa...
# 3             Support shipping vehicles to the country
# 4    Provide TAFE places to train mechanics in the ...
# ..                                                 ...
# 236  See answers supplied by email and in the attac...
# 237                                                NaN
# 238                                                NaN
# 239  Please refer to the attached document for our ...
# 240  1. Subsidy of $50 per KW of EV battery pack if...
#
#     16. How can we expand our existing domestic heavy vehicle manufacturing and assembly capability?  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Priotising locally made heavy vehicle and bus ...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 236  See answers supplied by email and in the attac...
# 237                                                NaN
# 238                                                NaN
# 239  Please refer to the attached document for our ...
# 240  Subsidy of $50 per KW of EV battery pack if th...
#
#     1. Do you agree with the objectives and do you think they will achieve our proposed goals? Are there other objectives we should consider?  \
# 0    I agree with the current objectives, however s...
# 1                                                  NaN
# 2    It's unclear whether "establishing systems and...
# 3    We should not tie ourselves to Australian manu...
# 4    The objectives should be broadened to include ...
# ..                                                 ...
# 236  See answers supplied by email and in the attac...
# 237                             Please see my response
# 238  Yes and yes.\nIncreasing fuel independence sho...
# 239  Please refer to the attached document for our ...
# 240                                                NaN
#
#     6. What information could help increase demand and is Government or industry best placed to inform Australians about EVs?  \
# 0    The Government should be informing Australians...
# 1    Government. "Industry", (the local distributor...
# 2    Government and industry both have a role to pl...
# 3    A similar body to the AER may be needed to assist
# 4    There is a role for both government and indust...
# ..                                                 ...
# 236  See answers supplied by email and in the attac...
# 237                                                NaN
# 238  Government to provide statistics on EV uptake ...
# 239  Please refer to the attached document for our ...
# 240  1. Wide spread dissemination of the % of Austr...
#
#     7. Are vehicle fuel efficiency standards an effective mechanism to reduce passenger and light commercial fleet emissions?  \
# 0    Yes, as shown in the EU etc. Please introduce ...
# 1                                                  NaN
# 2    Indications are that fuel efficiency standards...
# 3                                                   No
# 4    Yes, they are important in reducing emissions,...
# ..                                                 ...
# 236  See answers supplied by email and in the attac...
# 237                                                NaN
# 238                                                yes
# 239  Please refer to the attached document for our ...
# 240  Yes they help but would be more effective if t...
#
#     What area best describes where you live?  \
# 0                                       City
# 1                                       City
# 2                                       City
# 3                                       City
# 4                                       City
# ..                                       ...
# 236                                     City
# 237                                     City
# 238                                     City
# 239                                     City
# 240                            Regional area
#
#     18. Are there other proposals that could help drive demand for EVs and provide a revenue source to help fund road infrastructure?  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Fuel excise is not currently utilised for road...
# 3                                                  NaN
# 4    Distance-based road user charges for all vehic...
# ..                                                 ...
# 236  See answers supplied by email and in the attac...
# 237                                                NaN
# 238  The earlier proposed RUC policy is ideally sui...
# 239  Please refer to the attached document for our ...
# 240                                                NaN
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 236  ...
# 237  ...
# 238  ...
# 239  ...
# 240  ...
#
#     17. Is it viable to extend Australian domestic manufacturing and assembly capability to other vehicle classes?  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Absolutely and it is already being done for ma...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 236  See answers supplied by email and in the attac...
# 237                                                NaN
# 238                                                NaN
# 239  Please refer to the attached document for our ...
# 240  Yes and we should. For example: Offer land, su...
#
#     10. What design features should the Government consider in more detail for vehicle fuel efficiency standards, including level of ambition, who they should apply to, commencement date, penalties and enforcement?  \
# 0            World-best ambition, as soon as possible.
# 1                                                  NaN
# 2    Government should consider best practice stand...
# 3                                                  NaN
# 4    Adoption of European standards would be approp...
# ..                                                 ...
# 236  See answers supplied by email and in the attac...
# 237                                                NaN
# 238                                                NaN
# 239  Please refer to the attached document for our ...
# 240  2030 ban on new petrol and diesel vehicles sal...
#
#     20. How can we best make sure all Australians get access to the opportunities and benefits from the transition?  \
# 0    Make riding a bike safe and accessible, as thi...
# 1                                                  NaN
# 2    Structure incentives appropriately and look at...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 236  See answers supplied by email and in the attac...
# 237                                                NaN
# 238                                                NaN
# 239  Please refer to the attached document for our ...
# 240  Make the purchase of EV the only viable choice...
#
#                                 Make a general comment  \
# 0    I took two kids in a pram on a bus to a street...
# 1    If you want more EVs in Australia allow free t...
# 2    Australia is ready for bold and strong commitm...
# 3    People in high density housing have no chance ...
# 4    Thank you for the opportunity to make a submis...
# ..                                                 ...
# 236                                                NaN
# 237                                                NaN
# 238  The comments made in the submission may be rep...
# 239                                                NaN
# 240  Our business has made the transition to all EV...
#
#     9. In addition to vehicle fuel efficiency standards for passenger and light commercial vehicles, would vehicle fuel efficiency standards be an appropriate mechanism to increase the supply of heavy vehicle classes to Australia?  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Fuel efficiency standards would no doubt incre...
# 3                                                  NaN
# 4    Fuel efficiency standards for heavy vehicles a...
# ..                                                 ...
# 236  See answers supplied by email and in the attac...
# 237                                                NaN
# 238                                                NaN
# 239  Please refer to the attached document for our ...
# 240  Yes of course. It is essential to our survival...
#
#                                                 Titles number_of_q_answered  \
# 0                                      #460\nAnonymous                   14
# 1                                      #456\nAnonymous                   21
# 2                                      #438\nAnonymous                   46
# 3                                      #432\nAnonymous                   59
# 4                                      #352\nAnonymous                   77
# ..                                                 ...                  ...
# 236                               #466\nTim O'Loughlin                 4734
# 237                            #435\nVolgren Australia                 4765
# 238                                      #113\nWatts4U                 4786
# 239  #455\nWestern Sydney Regional Organisation of ...                 4812
# 240                    #315\nWhyalla Veterinary Clinic                 4831
#
#                                   links_crawled_listed keep_rows_bool  \
# 0    https://consult.dcceew.gov.au/national-electri...           True
# 1    https://consult.dcceew.gov.au/national-electri...           True
# 2    https://consult.dcceew.gov.au/national-electri...           True
# 3    https://consult.dcceew.gov.au/national-electri...           True
# 4    https://consult.dcceew.gov.au/national-electri...           True
# ..                                                 ...            ...
# 236  https://consult.dcceew.gov.au/national-electri...           True
# 237  https://consult.dcceew.gov.au/national-electri...           True
# 238  https://consult.dcceew.gov.au/national-electri...           True
# 239  https://consult.dcceew.gov.au/national-electri...           True
# 240  https://consult.dcceew.gov.au/national-electri...           True
#
#                                        combined_values
# 0    Yes, please.Please follow the Climate Council ...
# 1    Government. "Industry", (the local distributor...
# 2    Different measures are no doubt needed to supp...
# 3    Fuel should no longer be relevant in these dis...
# 4    Yes, fuel efficiency standards would send an i...
# ..                                                 ...
# 236  See answers supplied by email and in the attac...
# 237  Please see my responsePlease see my responseCi...
# 238  It is important to focus on the main polluters...
# 239  Please refer to the attached document for our ...
# 240  1. Provide free registration and accident insu...
#
# [241 rows x 28 columns]

# %%
M_clean_D = combined_df.loc[:,['combined_values']]

# %%
M_clean_D.isna().sum()
# Out:
# combined_values    0
# dtype: int64

# %%
M_clean_D.isna()
# Out:
#      combined_values
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ..               ...
# 236            False
# 237            False
# 238            False
# 239            False
# 240            False
#
# [241 rows x 1 columns]

# %%
M_clean_D.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 1 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   combined_values  241 non-null    object
# dtypes: object(1)
# memory usage: 2.0+ KB

# %%
M_clean_D.iloc[0,0]
# Out:
# 'Yes, please.Please follow the Climate Council policy for Sustainable Transport (noting this is aimed at the states and territories): https://www.climatecouncil.org.au/sustainable-transport-policies-states/Reallocate funding from highways and motorways to active and public transport.Fund safe, separated bike lane networks so people on electric bikes and scooters are not a danger to people walking.If possible, encourage the States and Territories to roll out enforced 30 km/h zones around schools, playgrounds, high streets, and other places where people want to walk or ride bikes.Help Australians live healthier lives by making walking, riding a bike, and taking the bus or train an easy and safe way to get around.Rapidly reduce sales of ICE vehiclesRapidly lower whole-of-sector transport emissions, in line with 1.5 degrees C, and with interim targetsIncrease modal share of bikes, other micromobility devices, buses, and trainsReallocate transport budget to active and public transport projects rather than motorways and roads that make it more difficult to walk and ride a bike in the cityIncrease the proportion of children who walk, ride a bike, or use public transport to get to schoolI agree with the current objectives, however some additions are required. Please include an objective to increase the use of electric cargo bikes for transport.I live in Sydney’s Inner West, and our streets are already congested with cars. More cars – even electric ones, just make our streets unsafe for people on bikes. Children cannot walk or ride to school.Please also use the Scottish car vehicle kilometres travelled reduction strategy to form an objective for this Strategy. https://www.transport.gov.scot/publication/a-route-map-to-achieve-a-20-per-cent-reduction-in-car-kilometres-by-2030/Include an objective to increase electric public transport modal share, particularly for interstate travel.Finally, include safety for our community as an objective. For example:All new vehicles should be fitted with speed limiters, and retrofits should be phased in and eventually mandatedIdle Off campaigns should be introduced around the country, perhaps through the planned Federal EPAConsider the phase out of imports of oversized utility vehicles, such as Chevrolet’s Silverado etc. These are too tall for our streets, and they emit far too much. They are also very dangerous and have huge blindspots.The Government should be informing Australians about the benefits of living without cars. Please see the Scottish work on reducing VKTs by 20% to see different narratives about modal shift. https://www.transport.gov.scot/publication/a-route-map-to-achieve-a-20-per-cent-reduction-in-car-kilometres-by-2030/Please lower congestion and road rage in our cities by giving people real alternatives to driving a car to go to the shops. The Netherlands is the best place in the world to ride a bike, but also to drive!Please also see the new campaign "Better Streets Australia", which aims to make our local spaces better https://www.betterstreets.info/Please inform our transport planners, engineers, and decision makers at all levels by providing funds for Council and State staff to attend courses such as "Designing for Pedestrians and Bicycle Riders" http://www.sustainabletransport.com.au/training1.htmlYes, as shown in the EU etc. Please introduce them in line with the EU ASAPCityMode shift policies – we need to be improving public transport access and frequency, electrifying the buses we have now. This is particularly true along urban corridors in Sydney such as the Hume Highway and Parramatta Rd. There should be high frequency rapid transit here, with dedicated lanes, rather than congestion from people driving private cars. We need a more accessible system.The Government should not be trying to sell the public more cars. Our transport system is already too dependent on private cars for transport – this is an inaccessible monopoly for many. We should be building our cities better. Mo ...

# %%
cleaned_data_01 = M_clean_D.map(first_step_cleaning)

# %%
cleaned_data_01.iloc[0,0]
# Out:
# 'yes, please.please follow the climate council policy for sustainable transport (noting this is aimed at the states and territories):   funding from highways and motorways to active and public transport.fund safe, separated bike lane networks so people on electric bikes and scooters are not a danger to people walking.if possible, encourage the states and territories to roll out enforced 30 km/h zones around schools, playgrounds, high streets, and other places where people want to walk or ride bikes.help australians live healthier lives by making walking, riding a bike, and taking the bus or train an easy and safe way to get around.rapidly reduce sales of ice vehiclesrapidly lower whole-of-sector transport emissions, in line with 1.5 degrees c, and with interim targetsincrease modal share of bikes, other micromobility devices, buses, and trainsreallocate transport budget to active and public transport projects rather than motorways and roads that make it more difficult to walk and ride a bike in the cityincrease the proportion of children who walk, ride a bike, or use public transport to get to schooli agree with the current objectives, however some additions are required. please include an objective to increase the use of electric cargo bikes for transport.i live in sydney’s inner west, and our streets are already congested with cars. more cars even electric ones, just make our streets unsafe for people on bikes. children cannot walk or ride to school.please also use the scottish car vehicle kilometres travelled reduction strategy to form an objective for this strategy.   an objective to increase electric public transport modal share, particularly for interstate travel.finally, include safety for our community as an objective. for example:all new vehicles should be fitted with speed limiters, and retrofits should be phased in and eventually mandatedidle off campaigns should be introduced around the country, perhaps through the planned federal epaconsider the phase out of imports of oversized utility vehicles, such as chevrolet’s silverado etc. these are too tall for our streets, and they emit far too much. they are also very dangerous and have huge blindspots.the government should be informing australians about the benefits of living without cars. please see the scottish work on reducing vkts by 20% to see different narratives about modal shift.   lower congestion and road rage in our cities by giving people real alternatives to driving a car to go to the shops. the netherlands is the best place in the world to ride a bike, but also to drive!please also see the new campaign better streets australia, which aims to make our local spaces better   inform our transport planners, engineers, and decision makers at all levels by providing funds for council and state staff to attend courses such as designing for pedestrians and bicycle riders   as shown in the eu etc. please introduce them in line with the eu asapcitymode shift policies we need to be improving public transport access and frequency, electrifying the buses we have now. this is particularly true along urban corridors in sydney such as the hume highway and parramatta rd. there should be high frequency rapid transit here, with dedicated lanes, rather than congestion from people driving private cars. we need a more accessible system.the government should not be trying to sell the public more cars. our transport system is already too dependent on private cars for transport this is an inaccessible monopoly for many. we should be building our cities better. more cars means less open greenspace, trees to cool our city and clean our air. more cars also means more people dying in traffic collisions.assist families to trial electric cargo bikes with good quality trials, such as those run by lug and carrie:  a national strategy for near zero emissions transport, with a 1.5 degree aligned target, and implement policies to get us there.new south walesplease do not incentivise hybrids  ...

# %%
# # for finding the very special characters
# rem_01 = cleaned_data_01.iloc[0,0][-3:-1]
# rem_02 = cleaned_data_01.iloc[0,0][-3:-2]
# rem_03 = cleaned_data_01.iloc[0,0][-167:-166]

# %%
# rem_03
# Out:
# '“'

# %%
cleaned_data_01.head()
# Out:
#                                      combined_values
# 0  yes, please.please follow the climate council ...
# 1  government. industry, (the local distributors ...
# 2  different measures are no doubt needed to supp...
# 3  fuel should no longer be relevant in these dis...
# 4  yes, fuel efficiency standards would send an i...

# %%
combined_df['cleaned_combined_text'] = cleaned_data_01['combined_values']

# %%
combined_df.iloc[:,-1]
# Out:
# 0      yes, please.please follow the climate council ...
# 1      government. industry, (the local distributors ...
# 2      different measures are no doubt needed to supp...
# 3      fuel should no longer be relevant in these dis...
# 4      yes, fuel efficiency standards would send an i...
#                              ...
# 236    see answers supplied by email and in the attac...
# 237    please see my responseplease see my responseci...
# 238    it is important to focus on the main polluters...
# 239    please refer to the attached document for our ...
# 240    1. provide free registration and accident insu...
# Name: cleaned_combined_text, Length: 241, dtype: object

# %%
combined_df.to_csv('CheckPoint_03_MK_P_01.csv',index=False)

# %% [markdown]
# # Check_Point_3

# %% [markdown]
# # Start from here after Semi Cleaning

# %%
Loaded_semi_cleaned_data = pd.read_csv('CheckPoint_03_MK_P_01.csv')

# %%
spacy.prefer_gpu()
# Out:
# True

# %%
# Load the pre-trained spaCy model
# en_core_web_trf
# en_core_web_sm
# nlp = spacy.load('en_core_web_trf')
if spacy.prefer_gpu():
    # load the en_core_web_trf model on GPU
    nlp = spacy.load("en_core_web_trf")

# %%
# Loaded_semi_cleaned_data.iloc[0,-1][13:]

# %%
nlp

# %% [markdown]
# # must be done multiple times with different slices and must be appended to text and labels, but after save and load cause, remember you have to restart kernel each time.

# %% [markdown]
# # Run bellow only if max is 6000

# %%
len(Loaded_semi_cleaned_data.iloc[:,-1]),Loaded_semi_cleaned_data.iloc[:,-1]
# Out:
# (241,
#  0      yes, please.please follow the climate council ...
#  1      government. industry, (the local distributors ...
#  2      different measures are no doubt needed to supp...
#  3      fuel should no longer be relevant in these dis...
#  4      yes, fuel efficiency standards would send an i...
#                               ...
#  236    see answers supplied by email and in the attac...
#  237    please see my responseplease see my responseci...
#  238    it is important to focus on the main polluters...
#  239    please refer to the attached document for our ...
#  240    1. provide free registration and accident insu...
#  Name: cleaned_combined_text, Length: 241, dtype: object)

# %%
count = list()

# %%
for i in range(len(Loaded_semi_cleaned_data.iloc[:,-1])):
    count.append(len(Loaded_semi_cleaned_data.iloc[i,-1]))

# %%
rows_to_do_nlp_later = []
for i in range(len(count)):
    if count[i]>10000:
        rows_to_do_nlp_later.append(i)

# %%
rows_to_do_nlp_later
# Out:
# [91, 123, 141, 142, 184, 190, 218, 225, 230]

# %%
len(count),count[123]
# Out:
# (241, 61968)

# %%
import numpy as np

# %%
np.array(count).max()
# Out:
# 61968

# %%
text_len_df = 0
label_len_df = 0

# %%
for i in range(len(Loaded_semi_cleaned_data.iloc[:,-1])):
    if i in rows_to_do_nlp_later:
        continue
    else:
        One_string_C_post_contents = Loaded_semi_cleaned_data.iloc[i,-1]
        print(len(One_string_C_post_contents))
        if len(One_string_C_post_contents) > 11000:
            print("length > 10000")
            break
        doc = nlp(One_string_C_post_contents)
        text = []
        labels = []
        for ent in doc.ents:
            text.append(ent.text)
            labels.append(ent.label_)
        with open('text_NER.txt', 'a') as f:
            for item in text:
                f.write(item + '\n')
        with open('labels_NER.txt', 'a') as f:
            for item in labels:
                f.write(item + '\n')
        text_len_df += len(text)
        label_len_df += len(labels)
        if text_len_df != label_len_df:
            print("lens not matched!!!!!!!!")
        print("index",i)
        print('text_len_df:  ',text_len_df)
        print('index:  ',label_len_df)
# Out:
# 5546
# index 0
# text_len_df:   33
# index:   33
# 2350
# index 1
# text_len_df:   56
# index:   56
# 8059
# index 2
# text_len_df:   91
# index:   91
# 950
# index 3
# text_len_df:   95
# index:   95
# 4845
# index 4
# text_len_df:   105
# index:   105
# 1247
# index 5
# text_len_df:   107
# index:   107
# 2938
# index 6
# text_len_df:   125
# index:   125
# 5580
# index 7
# text_len_df:   152
# index:   152
# 2226
# index 8
# text_len_df:   158
# index:   158
# 3587
# index 9
# text_len_df:   178
# index:   178
# 3137
# index 10
# text_len_df:   194
# index:   194
# 3695
# index 11
# text_len_df:   207
# index:   207
# 1433
# index 12
# text_len_df:   217
# index:   217
# 1448
# index 13
# text_len_df:   222
# index:   222
# 1025
# index 14
# text_len_df:   227
# index:   227
# 1804
# index 15
# text_len_df:   243
# index:   243
# 3110
# index 16
# text_len_df:   253
# index:   253
# 1829
# index 17
# text_len_df:   257
# index:   257
# 2479
# index 18
# text_len_df:   275
# index:   275
# 1599
# index 19
# text_len_df:   277
# index:   277
# 2809
# index 20
# text_len_df:   292
# index:   292
# 7181
# index 21
# text_len_df:   311
# index:   311
# 4038
# index 22
# text_len_df:   327
# index:   327
# 4262
# index 23
# text_len_df:   375
# index:   375
# 2424
# index 24
# text_len_df:   378
# index:   378
# 593
# index 25
# text_len_df:   381
# index:   381
# 4861
# index 26
# text_len_df:   396
# index:   396
# 3259
# index 27
# text_len_df:   425
# index:   425
# 1282
# index 28
# text_len_df:   428
# index:   428
# 1271
# index 29
# text_len_df:   433
# index:   433
# 7388
# index 30
# text_len_df:   451
# index:   451
# 906
# index 31
# text_len_df:   458
# index:   458
# 3716
# index 32
# text_len_df:   493
# index:   493
# 965
# index 33
# text_len_df:   500
# index:   500
# 1863
# index 34
# text_len_df:   512
# index:   512
# 4684
# index 35
# text_len_df:   561
# index:   561
# 2562
# index 36
# text_len_df:   571
# index:   571
# 1743
# index 37
# text_len_df:   572
# index:   572
# 2024
# index 38
# text_len_df:   575
# index:   575
# 3921
# index 39
# text_len_df:   588
# index:   588
# 2414
# index 40
# text_len_df:   598
# index:   598
# 471
# index 41
# text_len_df:   599
# index:   599
# 7670
# index 42
# text_len_df:   643
# index:   643
# 3251
# index 43
# text_len_df:   668
# index:   668
# 4722
# index 44
# text_len_df:   682
# index:   682
# 915
# index 45
# text_len_df:   686
# index:   686
# 3072
# index 46
# text_len_df:   703
# index:   703
# 6835
# index 47
# text_len_df:   726
# index:   726
# 432
# index 48
# text_len_df:   727
# index:   727
# 2301
# index 49
# text_len_df:   740
# index:   740
# 3261
# index 50
# text_len_df:   761
# index:   761
# 1833
# index 51
# text_len_df:   781
# index:   781
# 691
# index 52
# text_len_df:   782
# index:   782
# 2873
# index 53
# text_len_df:   796
# index:   796
# 3026
# index 54
# text_len_df:   805
# index:   805
# 3672
# index 55
# text_len_df:   821
# index:   821
# 2353
# index 56
# text_len_df:   824
# index:   824
# 2466
# index 57
# text_len_df:   834
# index:   834
# 1503
# index 58
# text_len_df:   846
# index:   846
# 1719
# index 59
# text_len_df:   850
# index:   850
# 1736
# index 60
# text_len_df:   869
# index:   869
# 1170
# index 61
# text_len_df:   879
# index:   879
# 5131
# index 62
# text_len_df:   923
# index:   923
# 5179
# index 63
# text_len_df:   944
# index:   944
# 1067
# index 64
# text_len_df:   945
# index:   945
# 2581
# index 65
# text_len_df:   957
# index:   957
# 4441
# index 66
# text_len_df:   983
# index:   983
# 2283
# index 67
# text_len_df:   992
# index:   992
# 4704
# index 68
# text_len_df:   1017
# index:   1017
# 535
# index 69
# text_len_df:   1019
# index:   1019
# 867
# index 70
# text_len_df:   1027
# index:   1027
# 1978
# index 71
# text_len_df:   1031
# index:   1031
# 2383
# index 72
# text_len_df:   1041
# index:   1041
# 6420
# index 73
# text_len_df:   1081
# index:   1081
# 2527
# index 74
# text_len_df:   1091
# index:   1091
# 7187
# index 75
# text_len_df:   1120
# index:   1120
# 3536
# index 76
# text_len_df:   1126
# index:   1126
# 7736
# index 77
# text_len_df:   1152
# index:   1152
# 1702
# index 78
# text_len_df:   1156
# index:   1156
# 293
# index 79
# text_len_df:   1156
# index:   1156
# 1024
# index 80
# text_len_df:   1163
# index:   1163
# 4265
# index 81
# text_len_df:   1207
# index:   1207
# 725
# index 82
# text_len_df:   1211
# index:   1211
# 4790
# index 83
# text_len_df:   1229
# index:   1229
# 2517
# index 84
# text_len_df:   1236
# index:   1236
# 1636
# index 85
# text_len_df:   1240
# index:   1240
# 296
# index 86
# text_len_df:   1241
# index:   1241
# 5474
# index 87
# text_len_df:   1278
# index:   1278
# 1614
# index 88
# text_len_df:   1282
# index:   1282
# 2156
# index 89
# text_len_df:   1295
# index:   1295
# 8615
# index 90
# text_len_df:   1320
# index:   1320
# 1944
# index 92
# text_len_df:   1324
# index:   1324
# 1112
# index 93
# text_len_df:   1326
# index:   1326
# 1065
# index 94
# text_len_df:   1333
# index:   1333
# 6938
# index 95
# text_len_df:   1364
# index:   1364
# 639
# index 96
# text_len_df:   1364
# index:   1364
# 4107
# index 97
# text_len_df:   1376
# index:   1376
# 1939
# index 98
# text_len_df:   1385
# index:   1385
# 3686
# index 99
# text_len_df:   1415
# index:   1415
# 2816
# index 100
# text_len_df:   1421
# index:   1421
# 372
# index 101
# text_len_df:   1426
# index:   1426
# 7940
# index 102
# text_len_df:   1463
# index:   1463
# 4681
# index 103
# text_len_df:   1486
# index:   1486
# 2975
# index 104
# text_len_df:   1496
# index:   1496
# 551
# index 105
# text_len_df:   1497
# index:   1497
# 1900
# index 106
# text_len_df:   1500
# index:   1500
# 6442
# index 107
# text_len_df:   1534
# index:   1534
# 4613
# index 108
# text_len_df:   1560
# index:   1560
# 2780
# index 109
# text_len_df:   1585
# index:   1585
# 6494
# index 110
# text_len_df:   1648
# index:   1648
# 5218
# index 111
# text_len_df:   1663
# index:   1663
# 7505
# index 112
# text_len_df:   1704
# index:   1704
# 8457
# index 113
# text_len_df:   1730
# index:   1730
# 1412
# index 114
# text_len_df:   1739
# index:   1739
# 3970
# index 115
# text_len_df:   1756
# index:   1756
# 3617
# index 116
# text_len_df:   1766
# index:   1766
# 2173
# index 117
# text_len_df:   1775
# index:   1775
# 1129
# index 118
# text_len_df:   1781
# index:   1781
# 4892
# index 119
# text_len_df:   1856
# index:   1856
# 490
# index 120
# text_len_df:   1857
# index:   1857
# 1573
# index 121
# text_len_df:   1860
# index:   1860
# 1940
# index 122
# text_len_df:   1868
# index:   1868
# 263
# index 124
# text_len_df:   1868
# index:   1868
# 294
# index 125
# text_len_df:   1869
# index:   1869
# 2601
# index 126
# text_len_df:   1879
# index:   1879
# 881
# index 127
# text_len_df:   1882
# index:   1882
# 3902
# index 128
# text_len_df:   1911
# index:   1911
# 570
# index 129
# text_len_df:   1911
# index:   1911
# 2542
# index 130
# text_len_df:   1932
# index:   1932
# 1671
# index 131
# text_len_df:   1946
# index:   1946
# 6113
# index 132
# text_len_df:   1960
# index:   1960
# 1393
# index 133
# text_len_df:   1966
# index:   1966
# 1742
# index 134
# text_len_df:   1982
# index:   1982
# 1903
# index 135
# text_len_df:   1991
# index:   1991
# 2570
# index 136
# text_len_df:   2007
# index:   2007
# 1471
# index 137
# text_len_df:   2015
# index:   2015
# 4653
# index 138
# text_len_df:   2029
# index:   2029
# 6747
# index 139
# text_len_df:   2044
# index:   2044
# 3988
# index 140
# text_len_df:   2061
# index:   2061
# 2598
# index 143
# text_len_df:   2066
# index:   2066
# 7171
# index 144
# text_len_df:   2080
# index:   2080
# 1192
# index 145
# text_len_df:   2091
# index:   2091
# 2565
# index 146
# text_len_df:   2108
# index:   2108
# 4295
# index 147
# text_len_df:   2134
# index:   2134
# 401
# index 148
# text_len_df:   2138
# index:   2138
# 948
# index 149
# text_len_df:   2141
# index:   2141
# 2343
# index 150
# text_len_df:   2156
# index:   2156
# 4011
# index 151
# text_len_df:   2175
# index:   2175
# 6511
# index 152
# text_len_df:   2211
# index:   2211
# 2275
# index 153
# text_len_df:   2214
# index:   2214
# 3461
# index 154
# text_len_df:   2233
# index:   2233
# 75
# index 155
# text_len_df:   2234
# index:   2234
# 6875
# index 156
# text_len_df:   2274
# index:   2274
# 3972
# index 157
# text_len_df:   2283
# index:   2283
# 365
# index 158
# text_len_df:   2284
# index:   2284
# 2813
# index 159
# text_len_df:   2310
# index:   2310
# 4142
# index 160
# text_len_df:   2354
# index:   2354
# 4585
# index 161
# text_len_df:   2359
# index:   2359
# 1908
# index 162
# text_len_df:   2369
# index:   2369
# 3268
# index 163
# text_len_df:   2392
# index:   2392
# 3646
# index 164
# text_len_df:   2405
# index:   2405
# 837
# index 165
# text_len_df:   2408
# index:   2408
# 5820
# index 166
# text_len_df:   2442
# index:   2442
# 3560
# index 167
# text_len_df:   2459
# index:   2459
# 3772
# index 168
# text_len_df:   2476
# index:   2476
# 5652
# index 169
# text_len_df:   2523
# index:   2523
# 1568
# index 170
# text_len_df:   2529
# index:   2529
# 3918
# index 171
# text_len_df:   2561
# index:   2561
# 815
# index 172
# text_len_df:   2569
# index:   2569
# 756
# index 173
# text_len_df:   2569
# index:   2569
# 4562
# index 174
# text_len_df:   2588
# index:   2588
# 1945
# index 175
# text_len_df:   2616
# index:   2616
# 6238
# index 176
# text_len_df:   2636
# index:   2636
# 3343
# index 177
# text_len_df:   2661
# index:   2661
# 2231
# index 178
# text_len_df:   2672
# index:   2672
# 1589
# index 179
# text_len_df:   2680
# index:   2680
# 679
# index 180
# text_len_df:   2682
# index:   2682
# 766
# index 181
# text_len_df:   2684
# index:   2684
# 9086
# index 182
# text_len_df:   2753
# index:   2753
# 6301
# index 183
# text_len_df:   2795
# index:   2795
# 6707
# index 185
# text_len_df:   2824
# index:   2824
# 4376
# index 186
# text_len_df:   2846
# index:   2846
# 1400
# index 187
# text_len_df:   2853
# index:   2853
# 4159
# index 188
# text_len_df:   2876
# index:   2876
# 2090
# index 189
# text_len_df:   2884
# index:   2884
# 1202
# index 191
# text_len_df:   2891
# index:   2891
# 5870
# index 192
# text_len_df:   2914
# index:   2914
# 3353
# index 193
# text_len_df:   2924
# index:   2924
# 4599
# index 194
# text_len_df:   2957
# index:   2957
# 5369
# index 195
# text_len_df:   2975
# index:   2975
# 1615
# index 196
# text_len_df:   2983
# index:   2983
# 6078
# index 197
# text_len_df:   3001
# index:   3001
# 9079
# index 198
# text_len_df:   3061
# index:   3061
# 394
# index 199
# text_len_df:   3061
# index:   3061
# 1052
# index 200
# text_len_df:   3072
# index:   3072
# 844
# index 201
# text_len_df:   3077
# index:   3077
# 1894
# index 202
# text_len_df:   3084
# index:   3084
# 2293
# index 203
# text_len_df:   3090
# index:   3090
# 7062
# index 204
# text_len_df:   3113
# index:   3113
# 2377
# index 205
# text_len_df:   3118
# index:   3118
# 3804
# index 206
# text_len_df:   3130
# index:   3130
# 2001
# index 207
# text_len_df:   3137
# index:   3137
# 5196
# index 208
# text_len_df:   3171
# index:   3171
# 3956
# index 209
# text_len_df:   3183
# index:   3183
# 3587
# index 210
# text_len_df:   3206
# index:   3206
# 5194
# index 211
# text_len_df:   3231
# index:   3231
# 5819
# index 212
# text_len_df:   3252
# index:   3252
# 4711
# index 213
# text_len_df:   3275
# index:   3275
# 879
# index 214
# text_len_df:   3277
# index:   3277
# 6341
# index 215
# text_len_df:   3296
# index:   3296
# 6555
# index 216
# text_len_df:   3325
# index:   3325
# 6540
# index 217
# text_len_df:   3352
# index:   3352
# 3685
# index 219
# text_len_df:   3358
# index:   3358
# 8638
# index 220
# text_len_df:   3379
# index:   3379
# 2998
# index 221
# text_len_df:   3400
# index:   3400
# 3522
# index 222
# text_len_df:   3409
# index:   3409
# 1209
# index 223
# text_len_df:   3419
# index:   3419
# 5986
# index 224
# text_len_df:   3465
# index:   3465
# 2709
# index 226
# text_len_df:   3485
# index:   3485
# 7189
# index 227
# text_len_df:   3508
# index:   3508
# 1461
# index 228
# text_len_df:   3510
# index:   3510
# 5298
# index 229
# text_len_df:   3542
# index:   3542
# 1752
# index 231
# text_len_df:   3555
# index:   3555
# 4523
# index 232
# text_len_df:   3571
# index:   3571
# 3059
# index 233
# text_len_df:   3585
# index:   3585
# 6590
# index 234
# text_len_df:   3625
# index:   3625
# 3046
# index 235
# text_len_df:   3650
# index:   3650
# 1112
# index 236
# text_len_df:   3650
# index:   3650
# 78
# index 237
# text_len_df:   3650
# index:   3650
# 7801
# index 238
# text_len_df:   3700
# index:   3700
# 1299
# index 239
# text_len_df:   3701
# index:   3701
# 4537
# index 240
# text_len_df:   3774
# index:   3774

# %%
rows_to_do_nlp_later
# Out:
# [91, 123, 141, 142, 184, 190, 218, 225, 230]

# %%
One_string_C_post_contents = Loaded_semi_cleaned_data.iloc[230,-1][:]

# %%
#No mor than 38000
len(One_string_C_post_contents)
# Out:
# 21294

# %% [markdown]
# # Carefull !!!!!!!!!!!!!!!!!!

# %%
doc = nlp(One_string_C_post_contents)

# %% [markdown]
# # Max alittle

# %%
text = []
labels = []

# %%
for ent in doc.ents:
    text.append(ent.text)
    labels.append(ent.label_)

# %%
with open('text_NER.txt', 'a') as f:
    for item in text:
        f.write(item + '\n')

# %%
with open('labels_NER.txt', 'a') as f:
    for item in labels:
        f.write(item + '\n')

# %% [markdown]
# # END of repeating

# %%
with open('text_NER.txt', 'r') as f:
    my_list = f.readlines()
text = [item.replace("\n","") for item in my_list]

# %%
len(text)
# Out:
# 4857

# %%
type(text)
# Out:
# list

# %%
with open('labels_NER.txt', 'r') as f:
    my_list = f.readlines()
labels = [item.replace("\n","") for item in my_list]

# %%
len(labels)
# Out:
# 4857

# %%
type(labels)
# Out:
# list

# %% [markdown]
# # max alittle

# %%
df = pd.DataFrame({"text":text,"labels":labels})

# %%
df
# Out:
#                    text    labels
# 0       climate council       ORG
# 1                 30 km  QUANTITY
# 2           australians      NORP
# 3         1.5 degrees c  QUANTITY
# 4                sydney       GPE
# ...                 ...       ...
# 4852  tesla owners club       ORG
# 4853         march 2016      DATE
# 4854        nearly 2000  CARDINAL
# 4855               100%   PERCENT
# 4856          australia       GPE
#
# [4857 rows x 2 columns]

# %%
df.to_csv("NER_CheckPoint_MK_P_01.csv",index=False)

# %% [markdown]
# # END of NER

# %% [markdown]
# # EDA With NER dataset

# %% [markdown]
# ## filter out the company of person because it is a bias and it apears every where :(

# %%
Ner_df = pd.read_csv("Hamed_NER_final.csv")
Ner_df
# Out:
#                                               text    labels
# 0                                  Tammy Duckworth    PERSON
# 1                                           months      DATE
# 2                                              one  CARDINAL
# 3                         the United States Senate       ORG
# 4                                       Tuberville    PERSON
# ...                                            ...       ...
# 4313                               Tammy Duckworth    PERSON
# 4314                               Tammy Duckworth    PERSON
# 4315  the Hispanic Housing Development Corporation       ORG
# 4316                         Hipolito (Paul) Roldn    PERSON
# 4317                                     thousands  CARDINAL
#
# [4318 rows x 2 columns]

# %% [markdown]
# # Done

# %% [markdown]
# # END Of Mohammad NER :|

# %% [markdown]
# # Step 2 of cleaning
